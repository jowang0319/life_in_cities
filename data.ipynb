# %%
import pandas as pd

# %%
green = pd.read_csv("cities/%_of_public_green_space_(parks_and_gardens)_.csv",encoding = "ISO-8859-1")

# %%
pop_in_city = pd.read_csv("cities/%_of_total_national_country_population_living_in_the_city.csv",encoding = "ISO-8859-1")

# %%
art_g = pd.read_csv("cities/Art_Galleries.csv",encoding = "ISO-8859-1")

# %%
v_of_art = pd.read_csv("cities/Average_daily_no._of_visits_to_top_5_Art_exhibitions.csv",encoding = "ISO-8859-1")

# %%
income = pd.read_csv("cities/Average_income_per_capita_per_year_(ppp)_-_Sheet1.csv",encoding = "ISO-8859-1")

# %%
bookshops = pd.read_csv('cities/Bookshops.csv',encoding='ISO-8859-1')

# %%
cinemas = pd.read_csv('cities/Cinemas.csv',encoding='ISO-8859-1')

# %%
education= pd.read_csv('cities/Education_level-%_with_degree_level_or_higher_-_Sheet1.csv',encoding='ISO-8859-1')

# %%
att_carnival = pd.read_csv('cities/Estimated_attendance_at_main_Carnival-Festival_as_%_of_city_population_-_Sheet1.csv',encoding='ISO-8859-1')

# %%
fes_cel = pd.read_csv('cities/Festivals_and_Celebrations_-_Sheet1_-_Festivals_and_Celebrations_-_Sheet1.csv',encoding='ISO-8859-1')

# %%
film_fes = pd.read_csv('cities/Film_festivals_-_Sheet1_-_Film_festivals_-_Sheet1.csv',encoding='ISO-8859-1')

# %%
foreign_born = pd.read_csv('cities/Foreign_born_population_%_-_Sheet1_(1)_-_Foreign_born_population_%_-_Sheet1_(1).csv',encoding='ISO-8859-1')

# %%
gdp = pd.read_csv('cities/GDP_(ppp)(million)_-_Sheet1.csv',encoding='ISO-8859-1')

# %%
area = pd.read_csv('cities/Geographical_area_size,_sq._km_-_Sheet1.csv',encoding='ISO-8859-1')

# %%
concert_hall = pd.read_csv('cities/Major_Concert_Halls_-_Sheet1_-_Major_Concert_Halls_-_Sheet1.csv',encoding='ISO-8859-1')

# %%
museum = pd.read_csv('cities/National_Museums_-_Sheet1.csv',encoding='ISO-8859-1')

# %%
club_disco = pd.read_csv('cities/Night_Clubs,_Discos_and_Dance_Halls_-_Sheet1_-_Night_Clubs,_Discos_and_Dance_Halls_-_Sheet1.csv',encoding='ISO-8859-1')

# %%
cinema_adm = pd.read_csv('cities/No._of_cinema_admissions_per_year_-_Sheet1.csv',encoding='ISO-8859-1')

# %%
inter_tourist = pd.read_csv('cities/No._of_international_tourists_per_year_-_Sheet1.csv',encoding='ISO-8859-1')

# %%
theo_performance = pd.read_csv('cities/No._of_theatrical_performances_at_all_theatres_per_year_-_Sheet1.csv',encoding='ISO-8859-1')

# %%
bars = pd.read_csv('cities/Number_of_bars_-_Sheet1_-_Number_of_bars_-_Sheet1.csv',encoding='ISO-8859-1')

# %%
dance_perf = pd.read_csv('cities/Number_of_dance_performances_per_year_-_Sheet1.csv',encoding='ISO-8859-1')

# %%
int_student = pd.read_csv('cities/Number_of_international_students_studying_in_the_city_-_Sheet1_-_Number_of_international_students_studying_in_the_city_-_Sheet1.csv',encoding='ISO-8859-1')

# %%
markets = pd.read_csv('cities/Number_of_markets_-_Sheet1_-_Number_of_markets_-_Sheet1.csv',encoding='ISO-8859-1')

# %%
Michelin = pd.read_csv('cities/Number_of_Michelin_star_restaurants_-_Sheet1-2.csv',encoding='ISO-8859-1')

# %%
music_perf = pd.read_csv('cities/Number_of_music_performances_per_year_-_Sheet1.csv',encoding='ISO-8859-1')

# %%
other_heritage = pd.read_csv('cities/Number_of_other_Heritage_Historical_Sites_-_Sheet1.csv',encoding='ISO-8859-1')

# %%
restaurant = pd.read_csv('cities/Number_of_restaurants_-_Sheet1_-_Number_of_restaurants_-_Sheet1.csv',encoding='ISO-8859-1')

# %%
theaters = pd.read_csv('cities/Number_of_theatres.csv',encoding='ISO-8859-1')

# %%
pop = pd.read_csv('cities/Total_population_number_-_Sheet1.csv',encoding='ISO-8859-1')

# %%
cinema_tick = pd.read_csv('cities/Total_value_of_cinema_ticket_sales_per_year_-_Sheet1.csv',encoding='ISO-8859-1')

# %%
heritage = pd.read_csv('cities/UNESCO_World_heritage_Sites_-_Sheet1_-_UNESCO_World_heritage_Sites_-_Sheet1.csv',encoding='ISO-8859-1')

# %%
m1=area.merge(green,how='left', left_on='City', right_on='City')

# %%
m2 = m1.merge(pop_in_city,how='left', left_on='City', right_on='City')

# %%
m3 = m2.merge(art_g,how='left', left_on='City', right_on='City')

# %%
m4= m3.merge(v_of_art,how='left', left_on='City', right_on='City')

# %%
m5 = m4.merge(income,how='left', left_on='City', right_on='City')

# %%
def get_dollar(income):
    income = obj(income)
    return income.replace("$","")

# %% [markdown]
# ######

# %%
m6 = m5.merge(bookshops,how='left', left_on='City', right_on='City')

# %%
m7 = m6.merge(cinemas,how='left', left_on='City', right_on='City')

# %%
m8 = m7.merge(education,how='left', left_on='City', right_on='City')

# %%
m9 = m8.merge(att_carnival,how='left', left_on='City', right_on='City')

# %%
m10 = m9.merge(fes_cel,how='left', left_on='City', right_on='City')

# %%
m11 = m10.merge(film_fes,how='left', left_on='City', right_on='City')

# %%
m12 = m11.merge(foreign_born,how='left', left_on='City', right_on='City')

# %%
m13 = m12.merge(gdp,how='left', left_on='City', right_on='City')

# %%
m14 = m13.merge(concert_hall,how='left', left_on='City', right_on='City')

# %%
m15 = m14.merge(museum,how='left', left_on='City', right_on='City')

# %%
m16 = m15.merge(club_disco,how='left', left_on='City', right_on='City')

# %%
m17 = m16.merge(cinema_adm,how='left', left_on='City', right_on='City')

# %%
m18 = m17.merge(inter_tourist,how='left', left_on='City', right_on='City')

# %%
m19 = m18.merge(theo_performance,how='left', left_on='City', right_on='City')

# %%
m20 = m19.merge(bars,how='left', left_on='City', right_on='City')

# %%
m21 = m20.merge(dance_perf,how='left', left_on='City', right_on='City')

# %%
m22 = m21.merge(int_student,how='left', left_on='City', right_on='City')

# %%
m23 = m22.merge(markets,how='left', left_on='City', right_on='City')

# %%
m24 = m23.merge(Michelin,how='left', left_on='City', right_on='City')

# %%
m25 = m24.merge(music_perf,how='left', left_on='City', right_on='City')

# %%
m26 = m25.merge(other_heritage,how='left', left_on='City', right_on='City')

# %%
m27 = m26.merge(restaurant,how='left', left_on='City', right_on='City')

# %%
m28 = m27.merge(theaters,how='left', left_on='City', right_on='City')

# %%
m29 = m28.merge(pop,how='left', left_on='City', right_on='City')

# %%
m30 = m29.merge(cinema_tick,how='left', left_on='City', right_on='City')

# %%
m31 = m30.merge(heritage,how='left', left_on='City', right_on='City')

# %%
data = m31

# %%
data['income_percap'].apply(get_dollar)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-181-201490bc9e73> in <module>()
# ----> 1 data['income_percap'].apply(get_dollar)
#
# /usr/local/lib/python3.5/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2218         else:
#    2219             values = self.asobject
# -> 2220             mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2221
#    2222         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:62658)()
#
# <ipython-input-180-9fa2ec157a7f> in get_dollar(income)
#       1 def get_dollar(income):
# ----> 2     income = obj(income)
#       3     return income.replace("$","")
#
# NameError: name 'obj' is not defined

# %%
data
# Out:
#                 City  area_size   green  pop_in_city_per art_galleries  \
# 0          Amsterdam      2,580  13.00%             14.2           196
# 1        Netherlands     41,540     NaN              NaN           NaN
# 2             Berlin        892  14.40%              4.2           421
# 3            Germany    357,124     NaN              NaN           NaN
# 4             Bogota        345   4.40%             16.3           NaN
# 5           Colombia  1,141,750     NaN              NaN           NaN
# 6           Brussels        161  18.80%             10.5           313
# 7            Belgium     30,528     NaN              NaN           NaN
# 8       Buenos Aires        200   8.90%              7.2           331
# 9          Argentina  3,761,274     NaN              NaN           NaN
# 10             Dubai      4,357   2.00%             24.9            62
# 11         Edinburgh        263  16.00%              9.2            80
# ...

# %%
data.to_csv('data.csv')

# %%
# Out:
#               City  area_size   green  pop_in_city_per art_galleries  \
# 0        Amsterdam      2,580  13.00%             14.2           196
# 1      Netherlands     41,540     NaN              NaN           NaN
# 2           Berlin        892  14.40%              4.2           421
# 3          Germany    357,124     NaN              NaN           NaN
# 4           Bogota        345   4.40%             16.3           NaN
# 5         Colombia  1,141,750     NaN              NaN           NaN
# 6         Brussels        161  18.80%             10.5           313
# 7          Belgium     30,528     NaN              NaN           NaN
# 8     Buenos Aires        200   8.90%              7.2           331
# 9        Argentina  3,761,274     NaN              NaN           NaN
# 10           Dubai      4,357   2.00%             24.9            62
# 11       Edinburgh        263  16.00%              9.2            80
# 12        Scotland     77,910     NaN              NaN           NaN
# ...
